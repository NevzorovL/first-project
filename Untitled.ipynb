# %%
import pandas as pd
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
pd.options.mode.chained_assignment = None

from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, roc_curve, roc_auc_score, accuracy_score

# %%
data = pd.read_csv('iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
features = data.drop('Species', axis=1)
target = data['Species']

features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, train_size=0.6, random_state=20, stratify=target)

# %%
model = RandomForestClassifier()
model.fit(features_train, target_train)
model_predict = model.predict(features_valid)

accuracy_score(target_valid, model_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dc2bc6ad940c> in <module>
#       3 model_predict = model.predict(features_valid)
#       4
# ----> 5 accuracy_score(target_valid, model_predict)
#
# NameError: name 'accuracy_score' is not defined
